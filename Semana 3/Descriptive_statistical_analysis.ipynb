# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDA0101ENSkillsNetwork20235326-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# # ***Data Analysis with Python.***
#
# Estimated time needed: **30** minutes
#
# ## ***Objectives.***
#
# After completing this lab you will be able to:
#
# *   Explore features or charecteristics to predict price of car.

# %% [markdown]
# $ \ $
#
# -----
#
# # ***Table of Contents.***
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <ol>
#     <li><a href="https://#import_data">Import Data from Module</a></li>
#     <li><a href="https://#pattern_visualization">Analyzing Individual Feature Patterns using Visualization</a></li>
#     <li><a href="https://#discriptive_statistics">Descriptive Statistical Analysis</a></li>
#     <li><a href="https://#basic_grouping">Basics of Grouping</a></li>
#     <li><a href="https://#correlation_causation">Correlation and Causation</a></li>
#     <li><a href="https://#anova">ANOVA</a></li>
# </ol>
#
# </div>
#
# <hr>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# $ \ $
#
# ## ***(1) Import Data from Module.***
#
# Load the data and store it in dataframe `df`:

# %%
path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'
df = pd.read_csv(path)
df.to_csv("data.csv")
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# $ \ $
#
# ## ***(2)  Analyzing Individual Feature Patterns Using Visualization.***
#
# We import visualization packages "Matplotlib" and "Seaborn".

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# $ \ $
#
# ## ***How to choose the right visualization method?***
#
# When visualizing individual variables, it is important to first understand what type of variable you are dealing with. This will help us find the right visualization method for that variable.

# %%
# list the data types for each column.
print(df.dtypes)
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Question  1.***
#
# What is the data type of the column "peak-rpm"?

# %%
df["peak-rpm"].astype
# Out:
# <bound method NDFrame.astype of 0      5000.0
# 1      5000.0
# 2      5000.0
# 3      5500.0
# 4      5500.0
#         ...
# 196    5400.0
# 197    5300.0
# 198    5500.0
# 199    4800.0
# 200    5400.0
# Name: peak-rpm, Length: 201, dtype: float64>

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# float64
# ```
#
# </details>

# %% [markdown]
# $ \ $
#
#
#
# For example, we can calculate the correlation between variables  of type "int64" or "float64" using the method "corr":

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# The diagonal elements are always one; we will study correlation more precisely Pearson correlation in-depth at the end of the notebook.

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Question  2.***
#
# Find the correlation between the following columns: bore, stroke, compression-ratio, and horsepower.
#
# ***Hint:*** if you would like to select those columns, use the following syntax: df[['bore','stroke','compression-ratio','horsepower']]

# %%
df[['bore','stroke','compression-ratio','horsepower']].corr()
# Out:
#                        bore    stroke  compression-ratio  horsepower
# bore               1.000000 -0.055390           0.001263    0.566936
# stroke            -0.055390  1.000000           0.187923    0.098462
# compression-ratio  0.001263  0.187923           1.000000   -0.214514
# horsepower         0.566936  0.098462          -0.214514    1.000000

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df[['bore', 'stroke', 'compression-ratio', 'horsepower']].corr()
# ```
#
# </details>

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Continuous Numerical Variables.***
#
# Continuous numerical variables are variables that may contain any value within some range. They can be of type "int64" or "float64". A great way to visualize these variables is by using scatterplots with fitted lines.
#
# In order to start understanding the (linear) relationship between an individual variable and the price, we can use "regplot" which plots the scatterplot plus the fitted regression line for the data. This will be useful later on for visualizing the fit of the simple linear regression model as well.

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Positive Linear Relationship.***
#
# Let's find the scatterplot of "engine-size" and "price".

# %%
# Engine size (tamaño de la maquina/grafica) as potential predictor variable of price.
sns.regplot(x="engine-size", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 53522.8928598825)

# %% [markdown]
# $ \ $
#
# ## ***Note (the previos graphic).***
#
# As the engine-size goes up, the price goes up (sube): this indicates a positive direct correlation between these two variables. Engine size seems like a pretty good predictor of price since the regression line is almost a perfect diagonal line.

# %% [markdown]
# $ \ $
#
# ## ***Example (correlation).***
#
# We can examine `the correlation between 'engine-size' and 'price'` and see that it's approximately 0.87.

# %%
df[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %% [markdown]
# $ \ $
#
# ## ***Example (scatterplot).***
#
# Highway (carretera) mpg is a potential predictor variable of price. Let's find the scatterplot of "highway-mpg" and "price".

# %%
sns.regplot(x="highway-mpg", y="price", data=df)

# %% [markdown]
# As highway-mpg goes up, the price goes down: this indicates an inverse/negative relationship between these two variables. Highway mpg could potentially be a predictor of price.

# %% [markdown]
# $ \ $
#
# ## ***Example (correlation).***
#
#
# We can examine the correlation between 'highway-mpg' and 'price' and see it's approximately -0.704.

# %%
df[['highway-mpg', 'price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Weak Linear Relationship.***
#
# Let's see if "peak-rpm" is a predictor variable of "price".

# %%
sns.regplot(x="peak-rpm", y="price", data=df)

# %% [markdown]
# Peak rpm does not seem like a good predictor of the price at all since the regression line is close to horizontal. Also, the data points are very scattered and far from the fitted line, showing lots of variability. Therefore, it's not a reliable variable (variable de confianza).

# %% [markdown]
# $ \ $
#
# ## ***Example (correlation).***
#
# We can examine the correlation between 'peak-rpm' and 'price' and see it's approximately -0.101616.

# %%
df[['peak-rpm','price']].corr()
# Out:
#           peak-rpm     price
# peak-rpm  1.000000 -0.101616
# price    -0.101616  1.000000

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Question  3 (a).***
#
# Find the correlation  between x="stroke" and y="price".
#
#
# ***`Hint:`*** if you would like to select those columns, use the following syntax: df[["stroke","price"]].

# %%
df[["stroke","price"]].corr()
# Out:
#          stroke    price
# stroke  1.00000  0.08231
# price   0.08231  1.00000

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# #The correlation is 0.0823, the non-diagonal elements of the table.
#
# df[["stroke","price"]].corr()
#
# ```
#
# </details>

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Question  3 (b).***
#
# <p>Given the correlation results between "price" and "stroke", do you expect a linear relationship?</p>
# <p>Verify your results using the function "regplot()".</p>
# </div>

# %%
sns.regplot(x="price", y="stroke", data=df)

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
#
# #There is a weak correlation between the variable 'stroke' and 'price.' as such regression will not work well. We can see this using "regplot" to demonstrate this.
#
# #Code:
# sns.regplot(x="stroke", y="price", data=df)
#
# ```
#
# </details>

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Categorical Variables.***
#
# These are ***`variables that describe a 'characteristic' of a data unit`***, and are selected from a small group of categories. The categorical variables can have the type "object" or "int64". A good way to visualize categorical variables is by using ***`boxplots`***.

# %% [markdown]
# $ \ $
#
# ## ***Example (boxplot).***
#
# Let's look at the relationship between "body-style" and "price".

# %%
sns.boxplot(x="body-style", y="price", data=df)

# %% [markdown]
# We see that the distributions of price between the different body-style categories have a significant overlap, so `body-style would not be a good predictor of price`.

# %% [markdown]
# $ \ $
#
# ## ***Example(boxplot).***
#
# Let's examine engine "engine-location" and "price":

# %%
sns.boxplot(x="engine-location", y="price", data=df)

# %% [markdown]
# Here we see that the distribution of price between these two engine-location categories, front and rear (delantero y trasero), are `distinct enough to take engine-location as a potential good predictor of price.`

# %% [markdown]
# $ \ $
#
# ## ***Example(boxplot).***
#
# Let's examine "drive-wheels" and "price".

# %%
# drive-wheels
sns.boxplot(x="drive-wheels", y="price", data=df)

# %% [markdown]
# Here we see that the distribution of price between the different drive-wheels categories differs. As such, drive-wheels `could potentially be a predictor of price.`

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Descriptive Statistical Analysis.***
#
# Let's first take a look at the variables by utilizing a description method.
#
# The describe function automatically computes basic statistics for all continuous variables. Any NaN values are automatically skipped (omitida) in these statistics.
#
# This will show:
#
# * The count of that variable.
# * The standard deviation (std).
# * The minimum value.
# * The IQR (Interquartile Range: 25%, 50% and 75%).
# * the maximum value.

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example (method describe).***
#
#
# We can apply the method "describe" as follows:

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example (method describe).***
#
# The default setting of "describe" skips(omite) variables of type object. We can apply the method "describe" on the variables of type 'object' as follows:

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
df.describe(include=['object'])
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %% [markdown]
# $ \ $
#
# ----
#
# # ***Value Counts.***
#
# <p>Value counts is a good way of understanding how many units of each characteristic/variable we have.

# %% [markdown]
# $ \ $
#
# ## ***Example(value counts).***
#
# We can apply the "value_counts" method on the column "drive-wheels".

# %%
df['drive-wheels'].value_counts()
# Out:
# fwd    118
# rwd     75
# 4wd      8
# Name: drive-wheels, dtype: int64

# %%
df[['drive-wheels']].value_counts()
# Out:
# drive-wheels
# fwd             118
# rwd              75
# 4wd               8
# dtype: int64

# %%
print(type(df['drive-wheels'].value_counts()))
# Out:
# <class 'pandas.core.series.Series'>

# %% [markdown]
# $ \ $
#
# ## ***Note(value counts).***
#
# Don’t forget the method "value_counts" only works on pandas series, not pandas dataframes. As a result, we only include one bracket ***`df['drive-wheels']`***, not two brackets ***`df[['drive-wheels']]`***.

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example (value_counts to dataframe).***
#
# We can convert the series to a dataframe as follows:

# %%
# we create a variable called new that is df['drive-wheels'].value_counts()
new = df['drive-wheels'].value_counts()

# we change the format of new
new_dataframe = new.to_frame()

# we show in screen the previous result
print(type(new_dataframe), "\n\n")
new_dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      drive-wheels
# fwd           118
# rwd            75
# 4wd             8

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example (value_counts to dataframe).***
#
# Let's repeat the above steps but save the results to the dataframe "drive_wheels_counts" and rename the column  'drive-wheels' to 'value_counts'.

# %%
#(1) we create a dataframe called drive_wheels_counts from df['drive-wheels'].value_counts()
drive_wheels_counts = df['drive-wheels'].value_counts().to_frame()

#(2) We change the names of the columns
drive_wheels_counts.rename(columns={'drive-wheels': 'value_counts'}, inplace=True)

#(3) we show on the screen the results
drive_wheels_counts
# Out:
#      value_counts
# fwd           118
# rwd            75
# 4wd             8

# %% [markdown]
# $ \ $
#
# ----
#
# ### ***Example(rename of the name of the column index).***
#
# Now let's rename ***`the name of the column index`*** to 'drive-wheels':

# %%
(drive_wheels_counts).index.name = 'drive-wheels'
drive_wheels_counts
# Out:
#               value_counts
# drive-wheels
# fwd                    118
# rwd                     75
# 4wd                      8

# %% [markdown]
# $ \ $
#
# ----
#
# ### ***Example(rename of the name of the column index).***
#
# We can repeat the above process for the variable 'engine-location'.

# %%
df['engine-location'].value_counts()
# Out:
# front    198
# rear       3
# Name: engine-location, dtype: int64

# %%
#(1) we create a dataframe called engine_loc_counts from df['engine-location'].value_counts()
engine_loc_counts = df['engine-location'].value_counts().to_frame()

#(2) We change the names of the columns
engine_loc_counts.rename(columns={'engine-location': 'value_counts'}, inplace=True)

#(3) We rename the name of the column index to 'engine-location'
engine_loc_counts.index.name = 'engine-location'

#(4) We show in the screen the results
engine_loc_counts
# Out:
#                  value_counts
# engine-location
# front                     198
# rear                        3

# %% [markdown]
# <p>After examining the value counts of the engine location (ubicación del motor), we see that engine location would not be a good predictor variable for the price. This is because we only have three cars with a rear engine and 198 with an engine in the front, so this result is skewed (disperso o sesgado). Thus, we are not able to draw any conclusions about the engine location.</p>

# %% [markdown]
# $ \ $
#
# ----
#
#
# # ***Basics of Grouping.***
#
# <p>The "groupby" method groups data by different categories. The data is grouped based on one or several variables, and analysis is performed on the individual groups.</p>

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example (grouping).***
#
# We see that ***`"drive-wheels"`*** has 3 different categories of drive wheels.

# %%
df['drive-wheels'].head()
# Out:
# 0    rwd
# 1    rwd
# 2    rwd
# 3    fwd
# 4    4wd
# Name: drive-wheels, dtype: object

# %%
df['drive-wheels'].unique()
# Out:
# array(['rwd', 'fwd', '4wd'], dtype=object)

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Example(select apropiate columns to work with and get the avarage of a clustered dataframe).***
#
# We can select the columns 'drive-wheels', 'body-style' and 'price', then assign it to the variable "df_group_one".

# %%
#(1) Creamos un nuevo dataframe apartir de df y las columnas 'drive-wheels','body-style','price'
df_group_one = df[['drive-wheels','body-style','price']]

#(2) mostramos el resultado en pantalla. Aqui se puede ver que no estan agrupados respecto a la columna "drive-wheels".
df_group_one.head(10)
# Out:
#   drive-wheels   body-style    price
# 0          rwd  convertible  13495.0
# 1          rwd  convertible  16500.0
# 2          rwd    hatchback  16500.0
# 3          fwd        sedan  13950.0
# 4          4wd        sedan  17450.0
# 5          fwd        sedan  15250.0
# 6          fwd        sedan  17710.0
# 7          fwd        wagon  18920.0
# 8          fwd        sedan  23875.0
# 9          rwd        sedan  16430.0

# %% [markdown]
# $ \ $
#
#
# We can then calculate the average price for each of the different categories of data.

# %%
#(1) agrupamos nuestro el dataframe df_group_one usando la columna 'drive-wheels'.
# Esta es la forma natural de proceder, pero al parecer hay un error y hay que trabajar como se muestra en el segundo literal.
# df_group_one = df_group_one.groupby(['drive-wheels'], as_index = False)

#(2) creamos un nuevo dataframe que nos brinda los promedios
promedio = df_group_one.groupby(['drive-wheels'], as_index = False).mean()

#(3) mostramos en pantalla nuestros resultados
promedio
# Out:
#   drive-wheels         price
# 0          4wd  10241.000000
# 1          fwd   9244.779661
# 2          rwd  19757.613333

# %% [markdown]
# From our data, it seems rear-wheel drive(rwd) vehicles are on average the most expensive, while 4-wheel(4wd) and front-wheel(fwd) are approximately the same in price.

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Example(group by multiple column variables).***
#
# Let's group by both ***`'drive-wheels' and 'body-style'`***. This groups the dataframe by the unique combination of 'drive-wheels' and 'body-style'.

# %%
#(1) we create a new dataframe caller df_test using the dataframe df and its columns 'drive-wheels','body-style','price'.
df_test = df[['drive-wheels','body-style','price']]

#(2) We take the dataframe df_test and group by the columns 'drive-wheels','body-style'.
grouped_test = df_test.groupby(['drive-wheels','body-style'],as_index=False).mean()

#(3) we show our results on the screen
grouped_test
# Out:
#    drive-wheels   body-style         price
# 0           4wd    hatchback   7603.000000
# 1           4wd        sedan  12647.333333
# 2           4wd        wagon   9095.750000
# 3           fwd  convertible  11595.000000
# 4           fwd      hardtop   8249.000000
# 5           fwd    hatchback   8396.387755
# 6           fwd        sedan   9811.800000
# 7           fwd        wagon   9997.333333
# 8           rwd  convertible  23949.600000
# 9           rwd      hardtop  24202.714286
# 10          rwd    hatchback  14337.777778
# 11          rwd        sedan  21711.833333
# 12          rwd        wagon  16994.222222

# %% [markdown]
# This grouped data is much easier to visualize when it is made into a pivot table.

# %% [markdown]
# $ \ $
#
# ----
#
# # ***Pivot table.***
#
#
# A pivot table is like an Excel spreadsheet, with one variable along the column and another along the row. We can convert the dataframe to a pivot table using the method "pivot" to create a pivot table from the groups.
#
#
# $ \ $
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Example(pivot table).***
#
# In this case, we will use the dataframe group_pivot, we leave the "drive-wheels" variable as the rows of the table, and pivot "body-style" to become the columns of the table.

# %%
#(1) We take the dataframe df_test and group by the columns 'drive-wheels','body-style'.
# grouped_test = df_test.groupby(['drive-wheels','body-style'],as_index=False).mean()

#(2) We show our results on the screen
grouped_test.head()
# Out:
#   drive-wheels   body-style         price
# 0          4wd    hatchback   7603.000000
# 1          4wd        sedan  12647.333333
# 2          4wd        wagon   9095.750000
# 3          fwd  convertible  11595.000000
# 4          fwd      hardtop   8249.000000

# %%
grouped_pivot = (grouped_test).pivot(index='drive-wheels',columns='body-style')
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# $ \ $
#
# Often, we won't have data for some of the pivot cells. We can fill these missing cells with the value 0, but any other value could potentially be used as well. It should be mentioned that missing data is quite a complex subject and is an entire course on its own.

# %%
#(1) llenamos los espacios que tienen NaN con 0.
grouped_pivot = grouped_pivot.fillna(0) 

#(2) Mostramos en pantalla nuestro resultado.
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %% [markdown]
# $ \ $
#
# ---
#
# ## ***Question 4.***
#
# <p>Use the "groupby" function to find the average "price" of each car based on "body-style".</p>
# </div>

# %%
#(1) we create a dataframe using df and the columns 'body-style' and 'price'.
new_dat=df[['body-style','price']]

#(2) we groupby 'body-style' the dataframe new_dat and we calculate the mean
new_data = new_dat.groupby(['body-style'],as_index=False).mean()

#(3) we show on the screen the results
new_data
# Out:
#     body-style         price
# 0  convertible  21890.500000
# 1      hardtop  22208.500000
# 2    hatchback   9957.441176
# 3        sedan  14459.755319
# 4        wagon  12371.960000

# %% [markdown]
# $ \ $
#
# -----
#
# # ***Heat map.***
#
# A Heat map works with a dataframe like a pivot table.

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example(heat map).***
#
# Let's use a heat map to visualize the `relationship between Body Style vs Price`.

# %%
grouped_pivot
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  0.0      0.000000   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
#(1) we describe the color of the heat map.
plt.pcolor(grouped_pivot, cmap='RdBu')

#(2) we describe the heatmap
plt.colorbar()

#(3) we show on screen the heatmap
plt.show()

# %% [markdown]
# The heatmap plots the target variable (price) proportional to colour with respect to the variables `'drive-wheel' and 'body-style'` on the vertical and horizontal axis, respectively. This allows us to visualize how the price is related to `'drive-wheel' and 'body-style'`.

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Example.***
#
# The default labels convey no useful information to us. Let's change that:

# %%
fig, ax = plt.subplots()
im = ax.pcolor(grouped_pivot, cmap='RdBu')

#label names
row_labels = grouped_pivot.columns.levels[1]
col_labels = grouped_pivot.index

#move ticks and labels to the center
ax.set_xticks(np.arange(grouped_pivot.shape[1]) + 0.5, minor=False)
ax.set_yticks(np.arange(grouped_pivot.shape[0]) + 0.5, minor=False)

#insert labels
ax.set_xticklabels(row_labels, minor=False)
ax.set_yticklabels(col_labels, minor=False)

#rotate label if too long
plt.xticks(rotation=90)

fig.colorbar(im)
plt.show()

# %% [markdown]
# Visualization is very important in data science, and Python visualization packages provide great freedom. We will go more in-depth in a separate Python visualizations course.

# %% [markdown]
# $ \ $
#
# -----
#
# # ***Correlation and Causation.***
#
# ***`Correlation:`*** a measure of the extent of interdependence between variables.
#
# ***`Causation:`*** the relationship between cause and effect between two variables.
#
# It is important to know the difference between these two. Correlation does not imply causation. Determining correlation is much simpler  the determining causation as causation may require independent experimentation.

# %% [markdown]
# $ \ $
#
# ### ***`Pearson Correlation`.***
#
#
# The Pearson Correlation measures the linear dependence between two variables X and Y.
#
# The resulting coefficient is a value between -1 and 1 inclusive, where:
#
# * 1 = Perfect positive linear correlation.
#
# * 0 = No linear correlation, the two variables most likely do not affect each other.
#
# * -1 = Perfect negative linear correlation.
#
# Pearson Correlation is the default method of the function "corr".

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Example (Pearson Correlation).***
#
#
# Like before, we can calculate the Pearson Correlation of the of the 'int64' or 'float64'  variables.</p>

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# Sometimes we would like to know the significant of the correlation estimate.

# %% [markdown]
# $ \ $
#
# ## ***`P-value`.***
#
# * ***What is this P-value?*** The P-value is the probability value that the correlation between these two variables is statistically significant.
#
#
# * Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.
#
# By convention, when the
#
# * ***p-value  $<$ 0.001:*** we say there is strong evidence that the correlation is significant.
#
# * ***0.001 $\leq$ p-value $<$ 0.05:*** there is moderate evidence that the correlation is significant.
#
# * ***0.05 $\leq$ p-value $<$ 0.1:*** there is weak evidence that the correlation is significant.
#
# * ***0.1 $\leq$ p-value:*** there is no evidence that the correlation is significant.

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Stats(p-value).***
#
# We can obtain this information using  "stats" module in the "scipy"  library.

# %%
from scipy import stats

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Example (person correlation and p-value betwenn "Wheel-Base" vs. "Price").***
#
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'wheel-base' and 'price'.

# %%
help(stats.pearsonr)
# Out:
# Help on function pearsonr in module scipy.stats.stats:
#
# pearsonr(x, y)
#     Pearson correlation coefficient and p-value for testing non-correlation.
#
#     The Pearson correlation coefficient [1]_ measures the linear relationship
#     between two datasets.  The calculation of the p-value relies on the
#     assumption that each dataset is normally distributed.  (See Kowalski [3]_
#     for a discussion of the effects of non-normality of the input on the
#     distribution of the correlation coefficient.)  Like other correlation
#     coefficients, this one varies between -1 and +1 with 0 implying no
#     correlation. Correlations of -1 or +1 imply an exact linear relationship.
#     Positive correlations imply that as x increases, so does y. Negative
#     correlations imply that as x increases, y decreases.
#
#     The p-value roughly indicates the probability of an uncorrelated system
#     producing datasets that have a Pearson correlation at least as extreme
# ...

# %%
pearson_coef, p_value = stats.pearsonr(df['wheel-base'], df['price'])
pearson_coef, p_value
# Out:
# (0.584641822265508, 8.076488270733218e-20)

# %%
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.584641822265508  with a P-value of P = 8.076488270733218e-20

# %%
if p_value < 0.001:
  print("There is strong evidence that the correlation is significant.")
elif 0.001  <=  p_value  <  0.05:
  print("There is moderate evidence that the correlation is significant.")
elif 0.05  <=  p_value  <  0.1:
  print("There is weak evidence that the correlation is significant")
elif 0.1  <=  p_value:
  print("There is no evidence that the correlation is significant")
# Out:
# There is strong evidence that the correlation is significant.

# %% [markdown]
# ***Conclusion.***
#
# Since the p-value is $<$ 0.001, the correlation between wheel-base and price is statistically significant, although the linear relationship isn't extremely strong (~0.585).

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example (person correlation and p-value betwenn "Horsepower" vs. "Price").***
#
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'horsepower' and 'price'.

# %%
pearson_coef, p_value = stats.pearsonr(df['horsepower'], df['price'])

print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8095745670036559  with a P-value of P =  6.369057428260101e-48

# %%
if p_value < 0.001: 
  print("There is strong evidence that the correlation is significant.")
elif 0.001  <=  p_value  <  0.05:
  print("There is moderate evidence that the correlation is significant.")
elif 0.05  <=  p_value  <  0.1:
  print("There is weak evidence that the correlation is significant")
elif 0.1  <=  p_value:
  print("There is no evidence that the correlation is significant")
# Out:
# There is strong evidence that the correlation is significant.

# %% [markdown]
# ***Conclusion.***
#
# Since the p-value is $<$ 0.001, the correlation between "horsepower" and "price" is statistically significant, and the linear relationship is quite strong (~0.809, close to 1).

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example (person correlation and p-value betwenn "Length" vs. "Price").***
#
# Let's calculate the  Pearson Correlation Coefficient and P-value of 'length' and 'price'.

# %%
pearson_coef, p_value = stats.pearsonr(df['length'], df['price'])

print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.6906283804483638  with a P-value of P =  8.016477466159556e-30

# %%
if p_value < 0.001:
  print("There is strong evidence that the correlation is significant.")
elif 0.001  <=  p_value  <  0.05:
  print("There is moderate evidence that the correlation is significant.")
elif 0.05  <=  p_value  <  0.1:
  print("There is weak evidence that the correlation is significant")
elif 0.1  <=  p_value:
  print("There is no evidence that the correlation is significant")
# Out:
# There is strong evidence that the correlation is significant.

# %% [markdown]
# ***Conclusion.***
#
#
# Since the p-value is $<$ 0.001, the correlation between "length" and "price" is statistically significant, and the linear relationship is moderately strong (~0.691).

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example (person correlation and p-value betwenn "Width" vs. "Price").***
#
# Let's calculate the Pearson Correlation Coefficient and P-value of 'width' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['width'], df['price'])

print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.7512653440522673  with a P-value of P = 9.200335510481646e-38

# %%
if p_value < 0.001:
  print("There is strong evidence that the correlation is significant.")
elif 0.001  <=  p_value  <  0.05:
  print("There is moderate evidence that the correlation is significant.")
elif 0.05  <=  p_value  <  0.1:
  print("There is weak evidence that the correlation is significant")
elif 0.1  <=  p_value:
  print("There is no evidence that the correlation is significant")
# Out:
# There is strong evidence that the correlation is significant.

# %% [markdown]
# ***Conclusion.***
#
# Since the p-value is < 0.001, the correlation between "width" and "price" is statistically significant, and the linear relationship is quite strong (\~0.751).

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example (person correlation and p-value betwenn "Curb-Weight" vs. "Price").***
#
# Let's calculate the Pearson Correlation Coefficient and P-value of 'curb-weight' and 'price':

# %%
pearson_coef, p_value = stats.pearsonr(df['curb-weight'], df['price'])

print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8344145257702843  with a P-value of P =  2.189577238894065e-53

# %%
if p_value < 0.001:
  print("There is strong evidence that the correlation is significant.")
elif 0.001  <=  p_value  <  0.05:
  print("There is moderate evidence that the correlation is significant.")
elif 0.05  <=  p_value  <  0.1:
  print("There is weak evidence that the correlation is significant")
elif 0.1  <=  p_value:
  print("There is no evidence that the correlation is significant")
# Out:
# There is strong evidence that the correlation is significant.

# %% [markdown]
# ***Conclusion.***
#
# Since the p-value is $<$ 0.001, the correlation between curb-weight and price is statistically significant, and the linear relationship is quite strong (~0.834).

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example (person correlation and p-value betwenn "engine-size" vs "price").***
#
#
# Let's calculate the Pearson Correlation Coefficient and P-value of "engine-size" and "price":

# %%
pearson_coef, p_value = stats.pearsonr(df['engine-size'], df['price'])

print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8723351674455185  with a P-value of P = 9.265491622198389e-64

# %%
if p_value < 0.001:
  print("There is strong evidence that the correlation is significant.")
elif 0.001  <=  p_value  <  0.05:
  print("There is moderate evidence that the correlation is significant.")
elif 0.05  <=  p_value  <  0.1:
  print("There is weak evidence that the correlation is significant")
elif 0.1  <=  p_value:
  print("There is no evidence that the correlation is significant")
# Out:
# There is strong evidence that the correlation is significant.

# %% [markdown]
# ***Conclusion.***
#
#
# Since the p-value is $<$ 0.001, the correlation between "engine-size" and "price" is statistically significant, and the linear relationship is very strong (~0.872).

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example (person correlation and p-value betwenn "Bore" vs. "Price").***
#
# Let's calculate the  Pearson Correlation Coefficient and P-value of "Bore" and "Price":

# %%
pearson_coef, p_value = stats.pearsonr(df['bore'], df['price'])

print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =  ", p_value )
# Out:
# The Pearson Correlation Coefficient is 0.5431553832626602  with a P-value of P =   8.049189483935489e-17

# %%
if p_value < 0.001:
  print("There is strong evidence that the correlation is significant.")
elif 0.001  <=  p_value  <  0.05:
  print("There is moderate evidence that the correlation is significant.")
elif 0.05  <=  p_value  <  0.1:
  print("There is weak evidence that the correlation is significant")
elif 0.1  <=  p_value:
  print("There is no evidence that the correlation is significant")
# Out:
# There is strong evidence that the correlation is significant.

# %% [markdown]
# ***Conclusion.***
#
#
# Since the p-value is $<$ 0.001, the correlation between "bore" and "price" is statistically significant, but the linear relationship is only moderate (~0.521).

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example (person correlation and p-value betwenn "City-mpg" vs. "Price").***
#
# Let's calculate the  Pearson Correlation Coefficient and P-value of "City-mpg" and "Price":

# %%
pearson_coef, p_value = stats.pearsonr(df['city-mpg'], df['price'])

print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.6865710067844678  with a P-value of P =  2.321132065567641e-29

# %%
if p_value < 0.001:
  print("There is strong evidence that the correlation is significant.")
elif 0.001  <=  p_value  <  0.05:
  print("There is moderate evidence that the correlation is significant.")
elif 0.05  <=  p_value  <  0.1:
  print("There is weak evidence that the correlation is significant")
elif 0.1  <=  p_value:
  print("There is no evidence that the correlation is significant")
# Out:
# There is strong evidence that the correlation is significant.

# %% [markdown]
# ***Conclusion.***
#
# Since the p-value is $<$ 0.001, the correlation between city-mpg and price is statistically significant, and the coefficient of about -0.687 shows that the relationship is negative and moderately strong.

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example (person correlation and p-value betwenn "Highway-mpg" vs. "Price").***
#
# Let's calculate the  Pearson Correlation Coefficient and P-value of "Highway-mpg" and "Price":

# %%
pearson_coef, p_value = stats.pearsonr(df['highway-mpg'], df['price'])

print( "The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value )
# Out:
# The Pearson Correlation Coefficient is -0.704692265058953  with a P-value of P =  1.7495471144476358e-31

# %%
if p_value < 0.001:
  print("There is strong evidence that the correlation is significant.")
elif 0.001  <=  p_value  <  0.05:
  print("There is moderate evidence that the correlation is significant.")
elif 0.05  <=  p_value  <  0.1:
  print("There is weak evidence that the correlation is significant")
elif 0.1  <=  p_value:
  print("There is no evidence that the correlation is significant")
# Out:
# There is strong evidence that the correlation is significant.

# %% [markdown]
# ***Conclusion.***
#
# Since the p-value is < 0.001, the correlation between highway-mpg and price is statistically significant, and the coefficient of about -0.705 shows that the relationship is negative and moderately strong.

# %% [markdown]
# $ \ $
#
# ----
#
# # ***ANOVA: `Analysis of Variance`.***
#
#
# The Analysis of Variance  (ANOVA) is a statistical method used to test whether there are significant differences between the means of two or more groups. ANOVA returns two parameters:
#
# * ***`F-test score:`*** ANOVA assumes the means of all groups are the same, calculates how much the actual means deviate from the assumption, and reports it as the F-test score. A larger score means there is a larger difference between the means.
#
# * ***`P-value:`***  P-value tells how statistically significant our calculated score value is.
#
# If our price variable is strongly correlated with the variable we are analyzing, we expect ANOVA to return a sizeable (considerable) F-test score and a small p-value.

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Note (anova and groupby).***
#
# Since ANOVA analyzes the difference between different groups of the same variable, the "groupby" function will come in handy (será útil).

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example (anova betwenn "Drive-Wheels" vs. "price").***
#
# Since ANOVA analyzes the difference between different groups of the same variable, the groupby function will come in handy. Because the ANOVA algorithm averages the data automatically, we do not need to take the average before hand.
#
# To see if different types of 'drive-wheels' impact  'price', we group the data.

# %%
#(1) we remember the dataframe df_test
df_test = df[['drive-wheels','body-style','price']]
df_test.head()
# Out:
#   drive-wheels   body-style    price
# 0          rwd  convertible  13495.0
# 1          rwd  convertible  16500.0
# 2          rwd    hatchback  16500.0
# 3          fwd        sedan  13950.0
# 4          4wd        sedan  17450.0

# %%
# we take a subdataframe of df_test taking just the columns 'drive-wheels' and 'price', and later we group by 'drive-wheels'
agrupamiento=df_test[['drive-wheels', 'price']].groupby(['drive-wheels'])
agrupamiento.head(2)
# Out:
#     drive-wheels    price
# 0            rwd  13495.0
# 1            rwd  16500.0
# 3            fwd  13950.0
# 4            4wd  17450.0
# 5            fwd  15250.0
# 136          4wd   7603.0

# %% [markdown]
# $ \ $
#
# We can obtain the values of the method group using the method "get_group".

# %%
agrupamiento.get_group('fwd')['price']
# Out:
# 3      13950.0
# 5      15250.0
# 6      17710.0
# 7      18920.0
# 8      23875.0
#         ...
# 185    11595.0
# 186     9980.0
# 187    13295.0
# 188    13845.0
# 189    12290.0
# Name: price, Length: 118, dtype: float64

# %%
agrupamiento.get_group('rwd')['price']
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 9      16430.0
# 10     16925.0
#         ...
# 196    16845.0
# 197    19045.0
# 198    21485.0
# 199    22470.0
# 200    22625.0
# Name: price, Length: 75, dtype: float64

# %%
agrupamiento.get_group('4wd')['price']
# Out:
# 4      17450.0
# 136     7603.0
# 140     9233.0
# 141    11259.0
# 144     8013.0
# 145    11694.0
# 150     7898.0
# 151     8778.0
# Name: price, dtype: float64

# %% [markdown]
# $ \ $
#
# We can use the function ***`'f_oneway'`*** in the module 'stats' to obtain the F-test score and P-value.

# %%
# We use the function f_oneway that describes F-test score and P-value. This is anova.
f_val, p_val = stats.f_oneway(agrupamiento.get_group('fwd')['price'], agrupamiento.get_group('rwd')['price'], agrupamiento.get_group('4wd')['price'])  
 
print("ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 67.95406500780399 , P = 3.3945443577151245e-23

# %% [markdown]
# This is a great result with a large F-test score showing a strong correlation and a P-value of almost 0 implying almost certain statistical significance. But does this mean all three tested groups are all this highly correlated?
#
# Let's examine them separately.

# %% [markdown]
# #### fwd and rwd

# %%
f_val, p_val = stats.f_oneway(agrupamiento.get_group('fwd')['price'], agrupamiento.get_group('rwd')['price'])  
 
print( "ANOVA results: F=", f_val, ", P =", p_val )
# Out:
# ANOVA results: F= 130.5533160959111 , P = 2.2355306355677845e-23

# %% [markdown]
# Let's examine the other groups.

# %% [markdown]
# #### 4wd and rwd

# %%
f_val, p_val = stats.f_oneway(agrupamiento.get_group('4wd')['price'], agrupamiento.get_group('rwd')['price'])  
   
print( "ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 8.580681368924756 , P = 0.004411492211225333

# %% [markdown]
# <h4>4wd and fwd</h4>

# %%
f_val, p_val = stats.f_oneway(agrupamiento.get_group('4wd')['price'], agrupamiento.get_group('fwd')['price'])  
 
print("ANOVA results: F=", f_val, ", P =", p_val)
# Out:
# ANOVA results: F= 0.665465750252303 , P = 0.41620116697845666

# %% [markdown]
# We notice that ANOVA for the categories `4wd` and `fwd` yields a high p-value > 0.1, so the calculated F-test score is not very statistically significant. This suggests we can't reject the assumption that the means of these two groups are the same, or, in other words, we can't conclude the difference in correlation to be significant.

# %% [markdown]
# <h3>Conclusion: Important Variables</h3>

# %% [markdown]
# <p>We now have a better idea of what our data looks like and which variables are important to take into account when predicting the car price. We have narrowed it down to the following variables:</p>
#
# Continuous numerical variables:
#
# <ul>
#     <li>Length</li>
#     <li>Width</li>
#     <li>Curb-weight</li>
#     <li>Engine-size</li>
#     <li>Horsepower</li>
#     <li>City-mpg</li>
#     <li>Highway-mpg</li>
#     <li>Wheel-base</li>
#     <li>Bore</li>
# </ul>
#
# Categorical variables:
#
# <ul>
#     <li>Drive-wheels</li>
# </ul>
#
# <p>As we now move into building machine learning models to automate our analysis, feeding the model with variables that meaningfully affect our target variable will improve our model's prediction performance.</p>
