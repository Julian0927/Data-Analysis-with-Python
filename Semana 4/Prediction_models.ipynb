# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkDA0101ENSkillsNetwork20235326-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# # ***Model Development.***
#
# Estimated time needed: **30** minutes
#
# ## ***Objectives.***
#
# After completing this lab you will be able to:
#
# *   Develop prediction models.

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Idea (this section).***
#
# In this section, we will develop several models that will predict the price of the car using the variables or features. This is just an estimate but should give us an objective idea of how much the car should cost.

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Questions (this section).***
#
# Some questions we want to ask in this module
#
#
# * Do I know if the dealer (distribuidor) is offering fair value for my trade-in (oferta)?
#
# * Do I know if I put a fair value on my car?

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Note (model development).***
#
# In data analytics, we often use Model Development to help us predict future observations from the data we have.

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Note (model to understand variables).***
#
# A model will help us understand the exact relationship between different variables and how these variables are used to predict the result.

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Import libraries.***
#
# We import the following libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Data that we will use in this section.***
#
# Load the data and store it in dataframe df.

# %%
#(1) We write the path that contain the info for this section.
path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv'

#(2) We charge the previous path.
df = pd.read_csv(path)

#(3) We charge in google colab the path 
df.to_csv("data.csv")

#(4) We show on screen the previous result.
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# $ \ $
#
# -----
#
# # ***Linear Regression and Multiple Linear Regression.***
#
# $ \ $
#
#
# ## ***Simple Linear Regression.***
#
#
# `Simple Linear Regression` is a method to help us understand the relationship between two variables:
#
# * The ***`predictor`/independent*** variable (X).
#
# * The ***`response`/dependent*** variable (that we want to predict)(Y).
#
# * The result of `Linear Regression` is a linear function that predicts the response (dependent) variable as a function of the predictor (independent) variable.
#
# $ \ $
#
# $$
# \begin{cases}
# X: Predictor \ Variables,\\ \\
# Y: Response \ Variable
# \end{cases}
# $$
#
# $ \ $
#
# * Normally is described by the linear function $ \ $ $Y = a + b  X$.

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Load the modules of linear regression.***
#
# Let's load the modules for linear regression.

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Creation of linear regression.***
#
# Create the linear regression object.

# %%
lm = LinearRegression()
lm
# Out:
# LinearRegression()

# %% [markdown]
# $ \ $
#
# -----
#
# ## ***Example ("highway-mpg" vs "price").***
#
# For this example, we want to look at how "highway-mpg" can help us predict car "price". Using simple linear regression, we will create a linear function with "highway-mpg" as the predictor variable and the "price" as the response variable.

# %%
X = df[['highway-mpg']]
Y = df[['price']]

# %% [markdown]
# $ \ $
#
# $(1)$ Fit the linear model using highway-mpg:

# %%
# lm = LinearRegression()
lm.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# $ \ $
#
# $(2)$ We can output a prediction:

# %%
# lm = LinearRegression()
# cómo funciona esta mierda?
Y_1 = lm.predict(X)

Y_1[0:5]
# Out:
# array([[16236.50464347],
#        [16236.50464347],
#        [17058.23802179],
#        [13771.3045085 ],
#        [20345.17153508]])

# %% [markdown]
# $ \ $
#
#
# $(3)$ What is the value of the intercept (a)?

# %%
lm.intercept_
# Out:
# array([38423.30585816])

# %% [markdown]
# $ \ $
#
# $(4)$ What is the value of the slope/pendiente (b)?

# %%
lm.coef_
# Out:
# array([[-821.73337832]])

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Question (1-a).***
#
# Create a linear regression object called "lm1".

# %%
lm1=LinearRegression()
lm1
# Out:
# LinearRegression()

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# lm1 = LinearRegression()
# lm1
# ```
#
# </details>

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Question (1-b).***
#
# Train the model using "engine-size" as the independent variable and "price" as the dependent variable.

# %%
X = df[["engine-size"]]
Y = df[["price"]]
lm1.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# lm1.fit(df[['engine-size']], df[['price']])
# lm1
# ```
#
# </details>

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Question (1-c).***
#
# Find the slope (pendiente) and intercept of the model.

# %%
#(1) We show the intercept
intercept = lm1.intercept_

#(2) We show the intercept with the Y axis
slope = lm1.coef_ 

#(3) We show on the screen the results
print(f"Intercept = {intercept}, Slope = {slope}")
# Out:
# Intercept = [-7963.33890628], Slope = [[166.86001569]]

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# # Slope
# lm1.coef_
#
# # Intercept
# lm1.intercept_
# ```
#
# </details>

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Question (1-d).***
#
# What is the equation of the predicted line?
#
# ***`Hint:`*** You can use x and y_1 or "engine-size" or "price".

# %%
#(1) We describe the intercept as a real number.
a=float(intercept)

#(2) We describe the slope as a real number.
b=float(slope)

#(3) We remember de dataframe X.
X = df[["engine-size"]]

#(5) We call y_1 as the equation of the predicted line.
Y_1 = a+b*X

#(6) We show on the screen the result of y_1
Y_1
# Out:
#       engine-size
# 0    13728.463134
# 1    13728.463134
# 2    17399.383479
# 3    10224.402804
# 4    14729.623228
# ..            ...
# 196  15563.923306
# 197  15563.923306
# 198  20903.443808
# 199  16231.363369
# 200  15563.923306
#
# [201 rows x 1 columns]

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# # using X and Y
# Yhat=-7963.34 + 166.86*X
#
# Price=-7963.34 + 166.86*engine-size
#
# ```
#
# </details>

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Multiple Linear Regression.***
#
#
#
# ***`Multiple Linear Regression`*** is very similar to Simple Linear Regression, but this method is used to explain the relationship between:
#
# * One continuous response (dependent) variable.
#
# * Two or more predictor (independent) variables.
#
#
# $ \ $
#
# $$
# \begin{cases}
# Y_1: Response \ Variable,\\ \\
# X_{1} :Predictor\ Variable \ 1,\\ \\
# X_{2} : Predictor\ Variable \ 2,\\ \\
# X_{3} : Predictor\ Variable \ 3,\\ \\
# X_{4} : Predictor\ Variable \ 4,\\ \\
# . \\
# . \\
# . \\ \\
# X_{n} : Predictor\ Variable \ n.
# \end{cases}
# $$
#
# $ \ $
#
# $$
# \begin{cases}
# a: intercept,\\ \\
# b_{1} :coefficients \ of\ Variable \ X_{1},\\ \\
# b_{2} :coefficients \ of\ Variable \ X_{2},\\ \\
# b_{3} :coefficients \ of\ Variable \ X_{3},\\ \\
# b_{4} :coefficients \ of\ Variable \ X_{4},\\ \\
# . \\
# . \\
# . \\ \\
# b_{n} :coefficients \ of\ Variable \ X_{n}.
# \end{cases}
# $$
#
# $ \ $
#
# The equation is given by:
#
# $$Y_{1} = a + b_{1} X_{1} + b_{2} X_{2} + b_{3} X_{3} + b_{4} X_{4}+\cdots+ b_{n} X_{n}. $$

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Note (regression models).***
#
#
# Most of the real-world regression models involve multiple predictors. We will illustrate the structure by using four predictor variables (polinomios de grado 1 con 4 variables), but these results can generalize to any integer (polinomios de grado 1 con $n$ variables).

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Note (previous section).***
#
# <p>From the previous section  we know that other good predictors of price could be:</p>
# <ul>
#     <li>Horsepower.</li>
#     <li>Curb-weight.</li>
#     <li>Engine-size.</li>
#     <li>Highway-mpg.</li>
# </ul>
# Let's develop a model using these variables as the predictor variables.

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Example (multiple linear regression).***
#
#
# $(a)$ Describe a subdataframe $Z$ from df using the columns 'horsepower', 'curb-weight', 'engine-size', 'highway-mpg'.

# %%
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
Z.head()
# Out:
#    horsepower  curb-weight  engine-size  highway-mpg
# 0       111.0         2548          130           27
# 1       111.0         2548          130           27
# 2       154.0         2823          152           26
# 3       102.0         2337          109           30
# 4       115.0         2824          136           22

# %% [markdown]
# $ \ $
#
# $(b)$ Fit (ajustar) the linear model using the four above-mentioned variables and the dataframe $df['price']$.

# %%
#(1) we create the linear regression.
lm = LinearRegression()

#(2) we fit the linear regression.
lm.fit(Z, df['price'])
# Out:
# LinearRegression()

# %% [markdown]
# $ \ $
#
# $(c)$ What is the value of the intercept(a)?

# %%
a=float(lm.intercept_)
a
# Out:
# -15806.62462632922

# %% [markdown]
# $ \ $
#
# $(d)$ What are the values of the coefficients $(b_{1}, b_{2}, b_{3}, b_{4})$?

# %%
lista=list(lm.coef_)
b_1=lista[0]
b_2=lista[1]
b_3=lista[2]
b_4=lista[3]

# %% [markdown]
# $ \ $
#
# ### ***Conclution.***
#
# As we saw above, we should get a final linear function with the structure:
#
# $$\begin{cases}
# Y_{1} = a + b_{1} X_{1} + b_{2} X_{2} + b_{3} X_{3} + b_{4} X_{4},\\ \\
# price= -15678.74 + 52.66 (horsepower) + 4.70  (curb-weight) + 81.96 (engine-size) + 33.58  (highway-mpg).
# \end{cases}
#  $$

# %%
data_work = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
data_work[['horsepower']] = b_1 * data_work[['horsepower']]
data_work[['curb-weight']] = b_2 * data_work[['curb-weight']]
data_work[['engine-size']] = b_3 * data_work[['engine-size']]
data_work[['highway-mpg']] = b_4 * data_work[['highway-mpg']]

print("Y_1 = a+b_1 x_1+b_2 x_2 + b_3 x_3+ b_4 x_4", "\n\n")
a+data_work.sum(axis=1)
# Out:
# Y_1 = a+b_1 x_1+b_2 x_2 + b_3 x_3+ b_4 x_4
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# 0      13699.111612
# 1      13699.111612
# 2      19051.654702
# 3      10620.361930
# 4      15521.314202
#            ...
# 196    16694.400437
# 197    19503.679202
# 198    20475.458380
# 199    17804.038813
# 200    17104.075080
# Length: 201, dtype: float64

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Question  (2-a).***
#
#
# Create and train (entrenar) a Multiple Linear Regression model "lm2" where the response variable is "price", and the predictor variables are "normalized-losses" and  "highway-mpg".
# </div>

# %%
lm2=LinearRegression()
X = df[["normalized-losses","highway-mpg"]]
Y = df[["price"]]
lm2.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# lm2 = LinearRegression()
# lm2.fit(df[['normalized-losses' , 'highway-mpg']],df['price'])
#
#
# ```
#
# </details>

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Question  (2-b).***
#
#
# Find the coefficient of the model.

# %%
lm2.coef_
# Out:
# array([[   1.49789586, -820.45434016]])

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# lm2.coef_
#
# ```
#
# </details>

# %% [markdown]
# $ \ $
#
# ----
#
# # ***Model Evaluation Using Visualization.***
#
# Now that we've developed some models, there is a natural question:
#
# $$\text{How do we evaluate our models and choose the best one?}$$
#
#
# One way to do this is by using a ***`visualization`***.

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Visualization package***
#
# Import the ***`visualization package`***, seaborn (nacido en el mar):

# %%
import seaborn as sns

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Regression Plot.***
#
# When it comes (Cuando se trata de) to ***`simple linear regression`***, an excellent way to visualize the fit (encajar) of our model is by using ***`regression plots`***. This plot will show a combination of:
#
# * A scattered (disperso) data points normally called a  scatterplot.
#
# * The fitted ***`linear regression`***  going through the data.
#
#
# This will give us a reasonable estimate of the relationship between the two variables, the strength (fuerza/intensidad) of the correlation, as well as the direction (positive or negative correlation).

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Example (regression plot).***
#
# Let's visualize ***`highway-mpg`*** as potential predictor variable of ***`price`***.

# %%
#(1) ancho de la imagen.
width = 12

#(2) largo de la imagen.
height = 10

#(3) configuramos el tamaño de la imagen teniendo en cuenta el ancho y largo descritos previamente.
plt.figure(figsize=(width, height))

#(4) Usamos el dataframe df y las columnas "highway-mpg" y "price" para realizar una grafica de regresión lineal.
sns.regplot(x="highway-mpg", y="price", data=df)

#(5) Esto es necesario no se por que.....
plt.ylim(0,)
# Out:
# (0.0, 48185.05976772564)

# %% [markdown]
# We can see from this plot that ***`price`*** is negatively correlated to ***`highway-mpg`*** since the regression slope (pendiente) is negative.

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Note(regression linear plot as a model).***
#
# One thing to keep in mind when looking at a regression plot is to pay attention to how scattered (exparcido) the data points are around the ***`regression line`***. This will give you a good indication of the variance of the data and whether a linear model would be the best fit or not. If the data is too far off (lejos) from the line, this linear model might not be the best model for this data.

# %% [markdown]
# $ \ $
#
# ---
#
# ## ***Example (regression linear plot).***
#
# Let's compare this plot to the regression plot of "peak-rpm" and "price".

# %%
#(1) Estabilizamos el mismo tamaño de figura al de la descrita anteriormente.
plt.figure(figsize=(width, height))

#(2) Usamos el dataframe df y las columnas "peak-rpm" y "price" para realizar una grafica de regresión lineal.
sns.regplot(x="peak-rpm", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 47414.1)

# %% [markdown]
# Comparing the regression plot of ***`"peak-rpm"`*** and ***`"highway-mpg"`***, we see that the points for ***`"highway-mpg"`*** are much closer to the generated line and, on average, decrease. The points for ***`"peak-rpm"`*** have more spread around the predicted line and it is much harder to determine if the points are decreasing or increasing as the ***`"peak-rpm"`*** increases.

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Question 3.***
#
# Given the regression plots above,
#
# $ \ $
#
# $$\text{Is "peak-rpm" or "highway-mpg" more strongly correlated with "price"?}$$
#
# $ \ $
#
# Use the method  ***`.corr()`*** to verify your answer.

# %%
df[["peak-rpm","highway-mpg","price"]].corr()
# Out:
#              peak-rpm  highway-mpg     price
# peak-rpm     1.000000    -0.058598 -0.101616
# highway-mpg -0.058598     1.000000 -0.704692
# price       -0.101616    -0.704692  1.000000

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# # The variable "highway-mpg" has a stronger correlation with "price", it is approximate -0.704692  compared to "peak-rpm" which is approximate -0.101616. You can verify it using the following command:
#
# df[["peak-rpm","highway-mpg","price"]].corr()
#
# ```
#
# </details>

# %% [markdown]
# $ \ $
#
# ----
#
#
# # ***Residual Plot.***
#
# A good way to visualize the variance of the data is to use a ***`residual plot`*** , but:
#
#
# $ \ $
#
# $$\text{What is a residual?}$$
#
# $ \ $
#
# The difference between the observed value $Y$ and the predicted value $Y_{1}$ is called the residual ($e=Y-Y_1$ / error). When we look at a regression plot, the residual is the distance from the data point to the fitted regression line.
#
# ---
#
# $ \ $
#
# $$\text{So what is a residual plot?}$$
#
# $ \ $
#
# A residual plot is a graph that shows the residuals on the vertical y-axis and the independent variable on the horizontal x-axis.
#
# ----
#
# $ \ $
#
# $$\text{What do we pay attention to when looking at a residual plot?}$$
#
# $ \ $
#
# * We look at the spread of the residuals. If the points in a residual plot are randomly spread out around the x-axis, then a linear model is appropriate for the data.
#
# * Why is that? Randomly spread out residuals means that the variance is constant, and thus the linear model is a good fit for this data.

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Example (residual plot).***
#
# Construct the residual plot between ***`'highway-mpg'`*** and ***`'price'`***.

# %%
#(1) ancho de la imagen.
width = 12

#(2) largo de la imagen.
height = 10

#(3) configuramos el tamaño de la imagen teniendo en cuenta el ancho y largo descritos previamente.
plt.figure(figsize=(width, height))

#(4) We built the residual plot with the dataframe df using the columns 'highway-mpg" and  "price".
sns.residplot(x=df['highway-mpg'], y=df['price'])
plt.show()

# %% [markdown]
# $ \ $
#
# $$ \text{What is this plot telling us?}$$
#
# $ \ $
#
# We can see from this residual plot that the residuals are not randomly spread around the x-axis, leading us to believe that maybe a non-linear model is more appropriate for this data.

# %% [markdown]
# $ \ $
#
# ----
#
# # ***Multiple Linear Regression (continuation / distribution plot).***
#
# $(1)$ How do we visualize a model for Multiple Linear Regression?
#
#
# This gets a bit more complicated because you can't visualize it with regression or residual plot.
#
# $(2)$ One way to look at the fit of the model is by looking at the ***`distribution plot`***. We can look at the distribution of the fitted values that result from the model and compare it to the distribution of the actual values.

# %% [markdown]
# $ \ $
#
# ----
#
# # ***Example (continuation / distribution plot).***
#
#
# $(1)$ First, let's make a prediction:

# %%
# We search what is the meaning of "lm.predict"
help(lm.predict)
# Out:
# Help on method predict in module sklearn.linear_model._base:
#
# predict(X) method of sklearn.linear_model._base.LinearRegression instance
#     Predict using the linear model.
#
#     Parameters
#     ----------
#     X : array-like or sparse matrix, shape (n_samples, n_features)
#         Samples.
#
#     Returns
#     -------
#     C : array, shape (n_samples,)
#         Returns predicted values.

# %%
#(1) Remember that lm is given as
lm=LinearRegression()

#(2) Remember that Z is described as:
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

#(3) Encajamos el objeto de regresion lineal lm con Z y df['price'].
lm.fit(Z, df['price'])

#(4) We use the predict method.
Y_1 = lm.predict(Z)

# %% [markdown]
# $ \ $
#
# $(2)$ Later we do a plot.

# %%
#(1) configuramos las medidas de la imagen establecidas anteriormente.
plt.figure(figsize=(width, height))

#(2) creamos la variable ax1 la cual describe el histograma de la columna 'price' del dataframe df.
ax1 = sns.histplot(df['price'], kde = True, color="r", label="Actual Value")

#(3) Mostramos los valores predecidos en Y_1 y los comparamos con el histograma anterior
sns.histplot(Y_1, kde = True, color="b", label="Fitted Values" , ax=ax1)

#(4) Configuramos el titulo de la imagen y los titulos del eje x y el eje y.
plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

#(5) Mostramos en pantalla el histograma (3)
plt.show()
plt.close()

# %% [markdown]
# $ \ $
#
# We can see that the `fitted values are reasonably close` to the actual values since the two distributions overlap a bit. However, there is definitely some room for improvement (mejoras).

# %% [markdown]
# $ \ $
#
# ----
#
# # ***Polynomial Regression and Pipelines (tuberías).***
#
#
# ***`Polynomial regression`*** is a general case of the general linear regression model or multiple linear regression models. We get non-linear relationships by squaring or setting higher-order terms of the predictor variables. There are different orders of polynomial regression:
#
# * ***`Quadratic`*** - 2nd Order.
# $$Y_1 = a + b_1 X +b_2 X^2.$$
#
# * ***`Cubic`*** - 3rd Order</b></center>
# $$Y_1 = a + b_1 X +b_2 X^2 +b_3 X^3.$$
#
# * ***`Higher-Order:`***
# $$
# Y_1 = a + b_1 X +b_2 X^2 +b_3 X^3+\cdots + b_n X^n.$$

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Remark (linear model is not a good model in general).***
#
# We saw earlier that a linear model did not provide the best fit while using "highway-mpg" as the predictor variable. Let's see if we can try fitting a polynomial model to the data instead.

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Important function to get plots.***
#
# We will use the following function to plot the data:

# %%
help(np.linspace)
# Out:
# Help on function linspace in module numpy:
#
# linspace(start, stop, num=50, endpoint=True, retstep=False, dtype=None, axis=0)
#     Return evenly spaced numbers over a specified interval.
#
#     Returns `num` evenly spaced samples, calculated over the
#     interval [`start`, `stop`].
#
#     The endpoint of the interval can optionally be excluded.
#
#     .. versionchanged:: 1.16.0
#         Non-scalar `start` and `stop` are now supported.
#
#     .. versionchanged:: 1.20.0
#         Values are rounded towards ``-inf`` instead of ``0`` when an
#         integer ``dtype`` is specified. The old behavior can
#         still be obtained with ``np.linspace(start, stop, num).astype(int)``
#
#     Parameters
#     ----------
#     start : array_like
#         The starting value of the sequence.
#     stop : array_like
#         The end value of the sequence, unless `endpoint` is set to False.
#         In that case, the sequence consists of all but the last of ``num + 1``
# ...

# %%
# np.linspace(a,b,n) realiza una partición regular del intervalo [a,b] de n puntos muestrales con n>=2.
np.linspace(15, 55, 4)
# Out:
# array([15.        , 28.33333333, 41.66666667, 55.        ])

# %%
# Esta funcion tambien la utilizaremos.
help(plt.gca)
# Out:
# Help on function gca in module matplotlib.pyplot:
#
# gca(**kwargs)
#     Get the current :class:`~matplotlib.axes.Axes` instance on the
#     current figure matching the given keyword args, or create one.
#
#     Examples
#     --------
#     To get the current polar axes on the current figure::
#
#         plt.gca(projection='polar')
#
#     If the current axes doesn't exist, or isn't a polar one, the appropriate
#     axes will be created and then returned.
#
#     See Also
#     --------
#     matplotlib.figure.Figure.gca : The figure's gca method.

# %%
# # Esta funcion tambien la utilizaremos.
help(plt.gcf)
# Out:
# Help on function gcf in module matplotlib.pyplot:
#
# gcf()
#     Get the current figure.
#
#     If no current figure exists, a new one is created using
#     `~.pyplot.figure()`.

# %%
# We construct a function called plot_pol (plot polinomy / grafica polinomica).
def plot_pol(model, independent_variable, dependent_variabble, Name):

    #(1) realizamos una partición con 100 elementos del intervalo [15,55].
    x_new = np.linspace(15, 55, 100)

    #(2) ejecutamos el modelo seleccionado sobre el arraw x_new.
    y_new = model(x_new)

    #(3) Realizamos un plot usando la variable dependiente Y y la variable independiente x, los puntos muestrales y el modelado.
    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')

    #(4) Describimos el título.
    plt.title('Polynomial Fit with Matplotlib for Price ~ Length')

    #(5) Gráfica
    ax = plt.gca()

    #(6) colores gráfica
    ax.set_facecolor((0.898, 0.898, 0.898))

    #(7)  Gráfica
    fig = plt.gcf()

    #(8) Describimos las etiquetas de los ejes
    plt.xlabel(Name)    
    plt.ylabel('Price of Cars')

    #(9) Mostramos el resultado en pantalla y cerramos.
    plt.show()
    plt.close()

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Example (aplication of the plot_pol function).***
#
# $(1)$ Let's get the variables:

# %%
#(1) independent variable.
x = df['highway-mpg']

#(2) dependent variablel
y = df['price']

# %% [markdown]
# $ \ $
#
# $(2)$ Let's fit the polynomial using the function ***`polyfit`***, then use the function ***`poly1d`*** to display the polynomial function.

# %%
#(1) Here we use a polynomial of the 3rd order (cubic). 
f = np.polyfit(x, y, 3)

#(2) Increible, que método utilizarán?
p = np.poly1d(f)

#(3) We show on the screen the result of (2).
print(p)
# Out:
#         3         2
# -1.557 x + 204.8 x - 8965 x + 1.379e+05

# %% [markdown]
# $ \ $
#
# $(3)$ Let's plot the function:

# %%
#(1) p = model = -1.557 x^3 + 204.8 x^2 - 8965 x + 1.379e+05.
#(2) x = independent variable = df['highway-mpg']
#(3) y = dependent variable = df['price']
#(4) 'highway-mpg'= name
plot_pol(p, x, y, 'highway-mpg')

# %% [markdown]
# $ \ $
#
# We can already see from plotting that this polynomial model performs better than the linear model. This is because the generated polynomial function  "hits" more of the data points.

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Question  4.***
#
# Create 11 order polynomial model with the variables x and y from above.

# %%
#(1) independent variable.
x = df['highway-mpg']

#(2) dependent variable.
y = df['price']

#(3) Here we use a polynomial of the 11 order (cubic). 
f = np.polyfit(x, y, 11)

#(4) Increible, que método utilizarán?
p = np.poly1d(f)

#(5) We use the plot_pol function with the previos variables.
plot_pol(p, x, y, 'highway-mpg')

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# # Here we use a polynomial of the 11 order (cubic)
# f = np.polyfit(x, y, 11)
# p = np.poly1d(f)
# plot_pol(p,x,y, 'Highway MPG')
#
# ```
#
# </details>

# %% [markdown]
# $ \ $
#
# -----
#
# # ***Remark (description of polynomial functions of several variables).***
#
# The analytical expression for Multivariate Polynomial function gets complicated.
#
# * Polynomial function of two - variables:  $ \ $ $Y_1=\sum \limits_{i,j} a_{(i,j)}X^{i}X^{j}$.
#
# * Polynomial function of three -  variables:  $ \ $ $Y_1=\sum \limits_{i,j,k} a_{(i,j,k)}X^{i}X^{j}X^{k}$.
#
# * Polynomial function of $ n$ - variables:  $ \ $ $Y_1=\sum \limits_{i_{1},\dots,i_{n}} a_{(i_{1},\dots,i_{n})}X^{i_{1}}\cdots X^{i_{n}}$.

# %% [markdown]
# $ \ $
#
# ----
#
# # ***Aplication of polynomial of several variables in data.***
#
# $(1)$ We can perform a polynomial transform on multiple features (caracteristivas / variables). First, we import the module:

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
# help(PolynomialFeatures)

# %% [markdown]
# $ \ $
#
# $(2)$ We create a ***`PolynomialFeatures`*** object of degree 2:

# %%
# help(PolynomialFeatures)

# %%
#(1) creamos el objeto de tipo polinomio de 2 variables con valores reales.
poly_feat = PolynomialFeatures(degree=2) 

#(2) mostramos en pantalla nuestro resultado
poly_feat
# Out:
# PolynomialFeatures()

# %%
#(1) Remember that Z is described as:
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

#(2) mostramos en pantalla los primeros elementos de Z.
Z.head()
# Out:
#    horsepower  curb-weight  engine-size  highway-mpg
# 0       111.0         2548          130           27
# 1       111.0         2548          130           27
# 2       154.0         2823          152           26
# 3       102.0         2337          109           30
# 4       115.0         2824          136           22

# %%
# luego de crear el objeto de tipo polinomio de 2 variables, le mostramos cuales sobre que variables trabajaremos
# help((poly_feat).fit_transform)

# %%
#(1) Remember that Z is described as:
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

#(2) No entiendo que hacen aqui.......
z_p = (poly_feat).fit_transform(Z)
z_p
# Out:
# array([[1.0000e+00, 1.1100e+02, 2.5480e+03, ..., 1.6900e+04, 3.5100e+03,
#         7.2900e+02],
#        [1.0000e+00, 1.1100e+02, 2.5480e+03, ..., 1.6900e+04, 3.5100e+03,
#         7.2900e+02],
#        [1.0000e+00, 1.5400e+02, 2.8230e+03, ..., 2.3104e+04, 3.9520e+03,
#         6.7600e+02],
#        ...,
#        [1.0000e+00, 1.3400e+02, 3.0120e+03, ..., 2.9929e+04, 3.9790e+03,
#         5.2900e+02],
#        [1.0000e+00, 1.0600e+02, 3.2170e+03, ..., 2.1025e+04, 3.9150e+03,
#         7.2900e+02],
#        [1.0000e+00, 1.1400e+02, 3.0620e+03, ..., 1.9881e+04, 3.5250e+03,
#         6.2500e+02]])

# %% [markdown]
# $ \ $
#
# -----
#
# # ***Pipelines (canalizaciones).***
#
# ***`Data Pipelines`*** (canalizaciones de datos) simplify the steps of processing the data. We use the module Pipeline (modelo canalizado) to create a pipeline (canal). We also use `StandardScaler` as a step in our pipeline (como un paso en nuestra canalización).

# %%
#(1) importamos pipeline (canal) de sklearn.pipeline.
from sklearn.pipeline import Pipeline

#(2) importamos StandardScaler (escaladora estándar) de sklearn.preprocessing.
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# $ \ $
#
# $(1)$ We create  a list of tuples including the name of the model or estimator and its corresponding constructor.

# %%
#(1) name of the "model" = LinearRegression().
#(2) PolynomialFeatures(include_bias=False) is the constructor (the creator of features).
#(3) we describe the "scale" using "StandardScaler".
Input=[('scale',StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model',LinearRegression())]

# %% [markdown]
# $ \ $
#
# $(2)$ We input (describimos como entrada) the list as an argument to the pipeline  constructor (constructor del canal):

# %%
#(1) pipe = tubo
# construimos el canal llamado "pipe" usando la función "Pipeline"
pipe = Pipeline(Input)

#(2) mostramos en pantalla el resultado
pipe
# Out:
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %% [markdown]
# $ \ $
#
# $(3)$ We convert the data type $Z$ to type float to avoid conversion warnings that may appear as a result of StandardScaler taking float inputs.

# %%
Z.head()
# Out:
#    horsepower  curb-weight  engine-size  highway-mpg
# 0       111.0         2548          130           27
# 1       111.0         2548          130           27
# 2       154.0         2823          152           26
# 3       102.0         2337          109           30
# 4       115.0         2824          136           22

# %%
Z.dtypes
# Out:
# horsepower     float64
# curb-weight      int64
# engine-size      int64
# highway-mpg      int64
# dtype: object

# %%
#(0) We remember the definition of y.
y = df['price']

#(1) we change the datatype of Z to float 64.
Z = Z.astype(float)

#(2) We print on the screen the datatype of Z
print(Z.dtypes, "\n\n")

#(3) Ajustamos Z a y.
pipe.fit(Z,y)
# Out:
# horsepower     float64
# curb-weight    float64
# engine-size    float64
# highway-mpg    float64
# dtype: object
# Pipeline(steps=[('scale', StandardScaler()),
#                 ('polynomial', PolynomialFeatures(include_bias=False)),
#                 ('model', LinearRegression())])

# %% [markdown]
# $ \ $
#
# $(4)$ Similarly,  we can normalize the data, perform a transform and produce a prediction  simultaneously.

# %%
#(1) Luego de ajustamos Z a y.
pipe.fit(Z,y)

#(2) Describimos la regresión lineal después de ajustar Z a y.
y_pipe=pipe.predict(Z)

#(3) Mostramos en pantalla los primeros 4 resultados.
y_pipe[0:4]
# Out:
# array([13102.74784201, 13102.74784201, 18225.54572197, 10390.29636555])

# %% [markdown]
# $ \ $
#
#
# ----
#
# #***Question 5.***
#
#
# Create a pipeline (canal) that standardizes the data, then produce a prediction using a `linear regression model` using the features $Z$ and target $y$.

# %%
#(1) We create the input to the function Pipeline.
entrada = [('scale',StandardScaler()), ('model',LinearRegression())]

#(2) pipe = tubo
canal=Pipeline(entrada)

#(3) We remember the dataframe Z.
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

#(4) We remember the dataframe y.
y = df['price']

#(5) Ajustamos Z a y.
canal.fit(Z,y)

#(6) Usamos predict.
y_pipe=canal.predict(Z)

#(7) mostramos en pantalla los primeros 4 resultados.
y_pipe[0:4]
# Out:
# array([13699.11161184, 13699.11161184, 19051.65470233, 10620.36193015])

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# Input=[('scale',StandardScaler()),('model',LinearRegression())]
#
# pipe=Pipeline(Input)
#
# pipe.fit(Z,y)
#
# ypipe=pipe.predict(Z)
# ypipe[0:4]
#
# ```
#
# </details>

# %% [markdown]
# $ \ $
#
# ----
#
# # ***Measures for In-Sample Evaluation.***
#
# When evaluating our models, not only do we want to visualize the results, but we also want a quantitative measure to determine how accurate (preciso) the model is. Two very important measures that are often used in Statistics to determine the accuracy  of a model are:
#
# * R^2 / R-squared.
#
# * Mean Squared Error (MSE).
#
# $ \ $
#
# ## ***`R-squared.`***
#
# ***`R - squared`***, also known as the coefficient of determination, is a measure to indicate how close the data is to the fitted regression line. The value of the ***R-squared*** is the percentage of variation of the response (response) variable $y$ that is explained by a linear model.
#
# $ \ $
#
# ## ***`Mean Squared Error (MSE / Mean Squared Error).`***
#
# The ***`Mean Squared Error (MSE)`*** measures the average of the squares of errors. That is, the difference between actual value $y$ and the estimated value $y_{1}$.

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Model 1: Simple Linear Regression.***
#
# ### ***`Example (R^2 of two sets of data)`***
#
# Let's calculate the coefficient of determination ($R^2$) of $X$ and $Y$.

# %%
#(1) We remember that X and Y have the following descrption.
X = df[["normalized-losses","highway-mpg"]]
Y = df[["price"]]

#(2) Remember that lm is given as:
lm=LinearRegression()

#(3) Encajamos X y Y.
lm.fit(X, Y)

#(3) Find the R^2
resultado = lm.score(X, Y)
print('The R-square is: ', resultado )
# Out:
# The R-square is:  0.4966263556974878

# %% [markdown]
# $ \ $
#
# We can say that $49.659 \%$ of the variation of the price is explained by this simple linear model "horsepower_fit".

# %% [markdown]
# $ \ $
#
# ### ***`Example (mean squared error of a set of data)`***
#
# Let's calculate the MSE of $X$ with the following steps:
#
# $ \ $
#
# $(1)$ We can predict the output $Y_1$ using the predict method, where $X$ is the input variable:

# %%
#(1) We remember the definition of X and Y
X = df[["normalized-losses","highway-mpg"]]
Y = df[["price"]]

#(2) We creat a linear regression object called lm
lm = LinearRegression()

#(3) We remember that previously we fit X and Y.
lm.fit(X, Y)

#(4) We predict X to get some aprroximation of Y
Y_1=lm.predict(X)

#(5) We show on the screen our result
print('The output of the first four predicted value is: ', Y_1[0:4])
# Out:
# The output of the first four predicted value is:  [[16231.78938339]
#  [16231.78938339]
#  [17052.24372355]
#  [13833.33798916]]

# %% [markdown]
# $ \ $
#
# $(2)$ Let's import the function ***`mean_squared_error`*** from the module metrics:

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# $ \ $
#
# $(3)$ We can compare the predicted results with the actual results:

# %%
#(1) We construct the mean squared error between Y_1 and Y=df['price'].
mse = mean_squared_error(Y, Y_1)

#(2) We show on the screen our previous result.
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  31632832.975589428

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Model 2: Multiple Linear Regression.***
#
# ### ***`Example (R^2 of two sets of data)`***
#
# Let's calculate the coefficient of determination ($R^{2}$) of  $Z$  and  $Y$ .

# %%
#(1) We remember that Z and Y have the following descrption.
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
Y = df[["price"]]

#(2) Remember that lm is given as:
lm=LinearRegression()

#(3) Encajamos Z y Y.
lm.fit(Z, Y)

#(3) Find the R^2
resultado = lm.score(Z, Y)
print('The R-square is: ', resultado )
# Out:
# The R-square is:  0.8093562806577457

# %% [markdown]
# $ \ $
#
# We can say that $80.896 \%$  of the variation of price is explained by this multiple linear regression "multi_fit".

# %% [markdown]
# $ \ $
#
# ### ***`Example (mean squared error of a set of data).`***
#
# Let's calculate the MSE of  $Z$  with respect to $Y$ with the following steps:
#
# $ \ $
#
# $(1)$  We can predict the output  $Y_{1}$  using the predict method, where  $Z$  is the input variable:

# %%
#(1) We remember the definition of X and Y
Z = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
Y = df[["price"]]

#(2) We creat a linear regression object called lm
lm = LinearRegression()

#(3) We remember that previously we fit X and Y.
lm.fit(Z, Y)

#(4) We predict X to get some aprroximation of Y
Y_1 = lm.predict(Z)

#(5) We show on the screen our result
print('The output of the first four predicted value is: ', Y_1[0:4])
# Out:
# The output of the first four predicted value is:  [[13699.11161184]
#  [13699.11161184]
#  [19051.65470233]
#  [10620.36193015]]

# %% [markdown]
# $ \ $
#
# $(2)$ We compare the predicted results with the actual results:

# %%
#(1) We construct the mean squared error between Y_1 and Y=df['price'].
mse = mean_squared_error(Y, Y_1)

#(2) We show on the screen our previous result.
print('The mean square error of price and predicted value is: ', mse)
# Out:
# The mean square error of price and predicted value is:  11980366.87072649

# %% [markdown]
# $ \ $
#
# ----
#
# ## ***Model 3: Polynomial Fit.***
#
# ### ***`Example (R^2 of two sets of data).`***
#
#
# Let's calculate the coefficient of determination ($R^{2}$) of $x$  and  $y$ using the following steps:

# %% [markdown]
# $(1)$ Let’s import the function $$\text{r2_score}$$ from the module <b>metrics</b> as we are using a different function.

# %%
from sklearn.metrics import r2_score

#(1) independent variable.
x = df['highway-mpg']

#(2) dependent variablel
y = df['price']

#(3) Here we use a polynomial of the 11 order (cubic). 
f = np.polyfit(x, y, 11)

#(4) Increible, que método utilizarán?
p = np.poly1d(f)

#(5) p(x) give us the result of evaluate the polinomy p in the different values of x.

#(6) We calculete the coefficient of determination of x and y using the polinomial p(x).
r_squared = r2_score(y, p(x))

#(7) We show on the screen the previous result.
print('The R-square value is: ', r_squared)
# Out:
# The R-square value is:  0.7023769093756598

# %% [markdown]
# $ \ $
#
# We can say that $70.238\%$ of the variation of price is explained by this polynomial fit.

# %% [markdown]
# $ \ $
#
# ### ***`Example (mse / mean squared error of a set of data).`***
#
# Let's calculate the MSE of  $x$ with respect to $y$ using a polinomial approximation of order 11 with the following steps:
#
# $ \ $
#
#
# *  We can predict the output  $p(x)$  using the least squares polynomial fit.
#
# $ \ $
#
# * We  calculate the mean squared error (mse) using the function ***`mean_squared_error`*** and the predict output.

# %%
#(1) We remember the data.
x = df['highway-mpg']
y = df['price']

#(2) We construct a polinomial object of orden 11.
f = np.polyfit(x, y, 11)
p = np.poly1d(f)

#(3) We show on the screen the mse between 
mean_squared_error(y, p(x))
# Out:
# 18703127.63085496

# %% [markdown]
# $ \ $
#
# ----
#
# # ***5. Prediction and Decision Making.***
#
#
# ## ***Determining a Good Model Fit.***

# %% [markdown]
# Now that we have visualized the different models, and generated the R-squared and MSE values for the fits, `how do we determine a good model fit?`
#
# $ \ $
#
# $(1)$ What is a good `R-squared (coefficient of determination)` value?
#
# When comparing models, <b>the model with the higher R-squared value is a better fit</b> for the data.
#
# $ \ $
#
# $(2)$ What is a good ` MSE (mean squared error)`?
#
# <p>When comparing models, <b>the model with the smallest MSE value is a better fit</b> for the data.

# %% [markdown]
# $ \ $
#
# Let's take a look at the values for the different models.
#
# $ \ $
#
# $(1)$ ***`Simple Linear Regression:`*** Using "Highway-mpg" as a Predictor Variable (variable independiente) of the variable "Price".
#
# * $R$-squared: 0.49659118843391759.
#
# * MSE: 3.16 x10^7.

# %% [markdown]
# $ \ $
#
#
# $(2)$ ***`Multiple Linear Regression:`*** Using Horsepower, Curb-weight, Engine-size, and Highway-mpg as Predictor Variables (variables independientes) of the variable "Price".
#
# * $R$-squared: 0.80896354913783497.
#
# * MSE: 1.2 x10^7.

# %% [markdown]
# $ \ $
#
# $(3)$ ***`Polynomial Fit:`*** Using Highway-mpg as a Predictor Variable (variable independiente) of the variable "Price".
#
# * $R$-squared: 0.6741946663906514.
#
# * MSE: 2.05 x 10^7.

# %% [markdown]
# $ \ $
#
# -----
#
# ### ***Simple Linear Regression Model (SLR) vs Multiple Linear Regression Model (MLR).***
#
#
# Usually, the more variables you have, the better your model is at predicting, but this is not always true. Sometimes you may not have enough data, you may run into numerical problems, or many of the variables may not be useful and even act as noise. As a result, `you should always check the MSE and R^2`.
#
#
#
# In order to compare the results of the MLR vs SLR (multilinear regression vs simple linear regression) models, we look at a combination of both the R-squared and MSE to make the best conclusion about the fit of the model.
#
#
# * ***`MSE:`*** The MSE of SLR is  3.16x10^7  while MLR has an MSE of 1.2 x10^7.  The MSE of MLR is much smaller.
#
# * ***`R-squared:`*** In this case, we can also see that there is a big difference between the R-squared of the SLR and the R-squared of the MLR. The R-squared for the SLR (0.497) is very small compared to the R-squared for the MLR (0.809).
#
#
#
# This R-squared in combination with the MSE show that MLR seems like the better model fit in this case compared to SLR.

# %% [markdown]
# $ \ $
#
# ### ***Simple Linear Model (SLR) vs. Polynomial Fit.***
#
# <ul>
#     <li><b>MSE</b>: We can see that Polynomial Fit brought down the MSE, since this MSE is smaller than the one from the SLR.</li>
#     <li><b>R-squared</b>: The R-squared for the Polynomial Fit is larger than the R-squared for the SLR, so the Polynomial Fit also brought up the R-squared quite a bit.</li>
# </ul>
# <p>Since the Polynomial Fit resulted in a lower MSE and a higher R-squared, we can conclude that this was a better fit model than the simple linear regression for predicting "price" with "highway-mpg" as a predictor variable.</p>

# %% [markdown]
# $ \ $
#
# ### ***Multiple Linear Regression (MLR) vs. Polynomial Fit.***
#
# <ul>
#     <li><b>MSE</b>: The MSE for the MLR is smaller than the MSE for the Polynomial Fit.</li>
#     <li><b>R-squared</b>: The R-squared for the MLR is also much larger than for the Polynomial Fit.</li>
# </ul>

# %% [markdown]
# $ \ $
#
# ----
#
# # ***Conclusion.***
#
# <p>Comparing these three models, we conclude that <b>the MLR model is the best model</b> to be able to predict price from our dataset. This result makes sense since we have 27 variables in total and we know that more than one of those variables are potential predictors of the final car price.</p>
